# %%
import pandas as pd

# %%
raw_train = pd.read_csv('./data/train.csv')

# %% [markdown]
# ### subset train based on category columns

# %%
train_cat_sub = raw_train
train_col_names = raw_train.columns.values

# %%
col_cat_filter = pd.read_csv('./output/raw_summary_cat_vs_gt80p.csv')

# %%
import numpy as np

# %%
x = col_cat_filter[col_cat_filter['69']>5]['cat7']
x = np.array(x)
x[:5]
# Out:
# array(['cat3', 'cat8', 'cat14', 'cat15', 'cat17'], dtype=object)

# %%
y = np.array(map(lambda i:i not in x, train_col_names))
train_col_names_sub = np.array(train_col_names)
train_col_names_sub = train_col_names_sub[y]
len(train_col_names_sub)
# Out:
# 68

# %%
train_cat_sub = raw_train[train_col_names_sub]
train_cat_sub.to_csv('./output/train_cat_sub_gt80.csv',encoding='utf-8')
train_cat_sub.head()
# Out:
#    id cat1 cat2 cat4 cat5 cat6 cat7 cat9 cat50 cat72   ...        cont6  \
# 0   1    A    B    B    A    A    A    B     A     A   ...     0.718367
# 1   2    A    B    A    A    A    A    B     A     A   ...     0.438917
# 2   5    A    B    A    B    A    A    B     A     A   ...     0.289648
# 3  10    B    B    B    A    A    A    B     A     A   ...     0.440945
# 4  11    A    B    B    A    A    A    B     A     B   ...     0.178193
#
#       cont7    cont8    cont9   cont10    cont11    cont12    cont13  \
# 0  0.335060  0.30260  0.67135  0.83510  0.569745  0.594646  0.822493
# 1  0.436585  0.60087  0.35127  0.43919  0.338312  0.366307  0.611431
# 2  0.315545  0.27320  0.26076  0.32446  0.381398  0.373424  0.195709
# 3  0.391128  0.31796  0.32128  0.44467  0.327915  0.321570  0.605077
# 4  0.247408  0.24564  0.22089  0.21230  0.204687  0.202213  0.246011
#
#      cont14     loss
# 0  0.714843  2213.18
# 1  0.304496  1283.60
# 2  0.774425  3005.09
# 3  0.602642   939.85
# 4  0.432606  2763.85
#
# [5 rows x 68 columns]

# %%
col_cat_filter = pd.read_csv('./output/raw_summary_cat_vs_gt60p.csv')
col_cat_filter.head()
# Out:
#     cat3  81
# 0   cat7  77
# 1   cat8  76
# 2   cat1  74
# 3  cat14  70
# 4  cat11  70

# %%
x = col_cat_filter[col_cat_filter['81']>5]['cat3']
x = np.array(x)
x[:5]
# Out:
# array(['cat7', 'cat8', 'cat1', 'cat14', 'cat11'], dtype=object)

# %%
y = np.array(map(lambda i:i not in x, train_col_names))
train_col_names_sub = np.array(train_col_names)
train_col_names_sub = train_col_names_sub[y]
train_cat_sub = raw_train[train_col_names_sub]
len(train_col_names_sub)

# %%
train_cat_sub.to_csv('./output/train_cat_sub_gt80.csv',encoding='utf-8')
train_cat_sub.head()
# Out:
#    id cat3 cat72 cat75 cat77 cat78 cat79 cat80 cat81 cat82   ...        cont6  \
# 0   1    A     A     B     D     B     B     D     D     B   ...     0.718367
# 1   2    A     A     A     D     B     B     D     D     A   ...     0.438917
# 2   5    A     A     A     D     B     B     B     D     B   ...     0.289648
# 3  10    A     A     A     D     B     B     D     D     D   ...     0.440945
# 4  11    A     B     A     D     B     D     B     D     B   ...     0.178193
#
#       cont7    cont8    cont9   cont10    cont11    cont12    cont13  \
# 0  0.335060  0.30260  0.67135  0.83510  0.569745  0.594646  0.822493
# 1  0.436585  0.60087  0.35127  0.43919  0.338312  0.366307  0.611431
# 2  0.315545  0.27320  0.26076  0.32446  0.381398  0.373424  0.195709
# 3  0.391128  0.31796  0.32128  0.44467  0.327915  0.321570  0.605077
# 4  0.247408  0.24564  0.22089  0.21230  0.204687  0.202213  0.246011
#
#      cont14     loss
# 0  0.714843  2213.18
# 1  0.304496  1283.60
# 2  0.774425  3005.09
# 3  0.602642   939.85
# 4  0.432606  2763.85
#
# [5 rows x 57 columns]
